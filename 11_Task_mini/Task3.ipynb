# %% [markdown]
# # Task 3 : Dealing with missing values

# %%
import pandas as pd
import numpy as np
df_activities = pd.read_csv("datasets\cardioActivities.csv",parse_dates = True , index_col= "Date")
df_activities
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running        NaN
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running        NaN
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running        NaN
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running        NaN
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running        NaN
# ...                                                   ...      ...        ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking        NaN
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking        NaN
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking        NaN
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running        NaN
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running        NaN
#
# ...

# %%
avg_hr_cycle =df_activities.groupby("Type").mean()
avg_hr_cycle
# Out:
#          Distance (km)  Average Speed (km/h)  Calories Burned   Climb (m)  \
# Type
# Cycling      23.468276             19.125172       558.482759  240.551724
# Other        17.225000             16.100000      1119.500000  210.500000
# Running      11.382353             11.056296     14656.621576  124.788671
# Walking       1.858333              5.549444    155300.777778   19.388889
#
#          Average Heart Rate (bpm)  Friend's Tagged
# Type
# Cycling                 124.40000              NaN
# Other                    85.50000              NaN
# Running                 144.98556              NaN
# Walking                       NaN              NaN

# %%
df_cycle = df_activities[df_activities["Type"]=="Cycling"].copy()
df_cycle
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling        NaN
# 2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8  Cycling        NaN
# 2018-09-01 17:06:15  2bd1841f-b428-4683-a41b-2bfb4be7e908  Cycling        NaN
# 2018-08-28 18:44:33  c9a8e088-441d-4b3f-bfbc-287e87585ca7  Cycling        NaN
# 2018-08-25 17:18:32  12723b6e-571b-4b68-be17-2c797982d3f9  Cycling        NaN
# 2017-09-22 12:27:14  4817879b-dedb-4b3d-a2e8-92d41757ccea  Cycling        NaN
# 2017-08-17 18:36:00  3c980f93-7aa1-477c-9f90-72ca01552031  Cycling        NaN
# 2017-05-01 17:38:35  9a5c1022-08f3-4c9b-9cc5-492d4d7178f9  Cycling        NaN
# 2016-10-03 11:47:16  d7f518d9-57aa-4c3f-b5d1-a3f758155737  Cycling        NaN
# 2016-09-10 17:13:51  be77ab12-11b2-4604-828d-6ac7ee0b6c50  Cycling        NaN
# 2016-09-04 17:08:28  cc9e2d95-fc5d-4633-9801-a6a92df8eebe  Cycling        NaN
# ...

# %%
df_cycle.head(5)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling        NaN
# 2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8  Cycling        NaN
# 2018-09-01 17:06:15  2bd1841f-b428-4683-a41b-2bfb4be7e908  Cycling        NaN
# 2018-08-28 18:44:33  c9a8e088-441d-4b3f-bfbc-287e87585ca7  Cycling        NaN
# 2018-08-25 17:18:32  12723b6e-571b-4b68-be17-2c797982d3f9  Cycling        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 
# 2018-08-28 18:44:33    111.0
# 2018-08-25 17:18:32    124.0
# 2017-09-22 12:27:14    124.4
# 2017-08-17 18:36:00    138.0
# 2017-05-01 17:38:35    135.0
# 2016-10-03 11:47:16    126.0
# 2016-09-10 17:13:51    136.0
# 2016-09-04 17:08:28    134.0
# 2016-08-27 17:08:38    134.0
# 2016-08-20 15:43:49    138.0
# 2016-08-17 17:17:09    122.0
# 2016-05-22 15:31:06    124.4
# 2015-10-18 15:43:06    124.4
# 2015-08-23 17:35:47    124.4
# 2015-08-15 18:46:21    124.4
# 2015-08-01 18:40:14    124.4
# 2015-06-21 17:53:46    124.4
# 2015-06-14 17:03:23    124.4
# 2015-06-06 18:30:39    124.4
# 2015-05-31 04:02:00    124.4
# 2015-05-23 19:07:40    124.0
# 2015-05-01 18:05:38    125.0
# 2014-08-29 18:56:02    124.4
# 2013-05-09 17:24:19    124.4
# 2013-05-05 14:26:37    124.4
# 2013-04-28 17:26:52    124.4
# Name: Average Heart Rate (bpm), dtype: float64

# %%
df_cycle['Average Heart Rate (bpm)'].fillna(124,inplace=True)
df_cycle.head(10)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling        NaN
# 2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8  Cycling        NaN
# 2018-09-01 17:06:15  2bd1841f-b428-4683-a41b-2bfb4be7e908  Cycling        NaN
# 2018-08-28 18:44:33  c9a8e088-441d-4b3f-bfbc-287e87585ca7  Cycling        NaN
# 2018-08-25 17:18:32  12723b6e-571b-4b68-be17-2c797982d3f9  Cycling        NaN
# 2017-09-22 12:27:14  4817879b-dedb-4b3d-a2e8-92d41757ccea  Cycling        NaN
# 2017-08-17 18:36:00  3c980f93-7aa1-477c-9f90-72ca01552031  Cycling        NaN
# 2017-05-01 17:38:35  9a5c1022-08f3-4c9b-9cc5-492d4d7178f9  Cycling        NaN
# 2016-10-03 11:47:16  d7f518d9-57aa-4c3f-b5d1-a3f758155737  Cycling        NaN
# 2016-09-10 17:13:51  be77ab12-11b2-4604-828d-6ac7ee0b6c50  Cycling        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# ...

# %%
df_run = print(df_activities.isnull().sum())
# Out:
# Activity Id                   0
# Type                          0
# Route Name                  507
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# Friend's Tagged             508
# Notes                       277
# GPX File                      4
# dtype: int64

# %%
df_run = print('Total null values in each column:\n\n ',df_activities.isnull().sum())
# Out:
# Total null values in each column:
#
#   Activity Id                   0
# Type                          0
# Route Name                  507
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# Friend's Tagged             508
# Notes                       277
# GPX File                      4
# dtype: int64
